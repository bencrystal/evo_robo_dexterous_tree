# %%
###########################NOTES##################################################################################

##################################################################################################################
import random
import sys
import copy
import pickle

# %run robot.ipynb      # This is how you run custom files in Jupyter Notebook
# %run individual.ipynb
# %run population.ipynb 
# %run constants.ipynb
# %run playback.ipynb




sys.path.append("/Documents/Documents/Senior Year/EvoRobo")



sys.path.insert(0, '../..')

import pyrosim # noqa
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
# %matplotlib notebook


# parent = INDIVIDUAL()



# parent.evaluate(True)
# print('[original parent:' , parent.fitness , ']')



# for i in range(0,100): # of robots
#     child = copy.deepcopy( parent )
#     child.mutate()
#     child.evaluate(True)

#     print('[Generation:' , i + 1 , ']' , '[Weight:' , parent.genome , ']' , '[p:' , parent.fitness , ']', '[c:' , child.fitness , ']')
    
#     if ( child.fitness > parent.fitness ):

#         parent = child
#         parent.evaluate(True)
        
#          #f = open('robot.p','wb')
#          #pickle.dump(parent , f )
#          #f.close()
####################################### 
parents = POPULATION(10)

parents.Evaluate(True)

exit()


parents.Print()

for g in range(0,200):

    children = copy.deepcopy(parents)

    children.Mutate()

    children.Evaluate(True)

    parents.ReplaceWith(children)

    print(g)
    
    parents.Print()


parents.Evaluate(False)
# Out:
# importing Jupyter notebook from constants.ipynb
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/Documents/playback.ipynb in <module>
#       6 f.close()
#       7
# ----> 8 best.Start_Evaluation(False)
#       9 # best.evaluate(False)
#      10 print(best.fitness)
#
# ~/Documents/playback.ipynb in Start_Evaluation(self, pb)
#      18     def Start_Evaluation(self, pb):
#      19         self.sim = pyrosim.Simulator( play_paused = True, eval_time = 400, play_blind = pb)
# ---> 20         self.robot = ROBOT( self.sim , self.genome )
#      21
#      22
#
# ~/Documents/playback.ipynb in __init__(self, sim, wts)
#      15         self.send_sensors(sim)
#      16         self.send_neurons(sim)
# ---> 17         self.send_synapses(sim, wts)
#      18
#      19
#
# ~/Documents/playback.ipynb in send_synapses(self, sim, wts)
#     181         for j in self.SN:
# ...
