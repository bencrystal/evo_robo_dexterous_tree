# %%
#this new robot is the pillar
# EDIT JOINT 0
# %run constants.ipynb
import import_ipynb
import constants
import sys
from numpy import random
sys.path.append("/Documents/Documents/Senior Year/EvoRobo")



class ROBOT:

    def __init__(self,sim,wts):
#sim = pyrosim.Simulator( play_paused = True, eval_time = 1000)
        print()
        self.send_objects(sim)
        self.send_joints(sim)
        self.send_sensors(sim)
        self.send_neurons(sim)
        self.send_synapses(sim, wts)
        
        

        
        
        
            #         sim.send_synapse(source_neuron_id = SN1 , target_neuron_id = MN2 , weight = wt )
#         sim.send_synapse(source_neuron_id = SN0 , target_neuron_id = MN2 , weight = -1.0 )
        
    
        del self.O
        del self.J
        del self.S
        del self.SN
        del self.MN
    
    def send_objects(self, sim):
        global whiteobject, redobject
        global O0, O1, O2, O3, O4, O5, O6, O7, O8, O9, O10, O11, O12, O13
#         whiteobject = sim.send_cylinder( x=0 , y=0 , z=.6 ,length=1.0 , radius=0.1 )
#         redobject = sim.send_cylinder( x=0 , y=.5 , z=1.1 , r = 1, g = 0, b = 0,r1=0 , r2=1, r3=0)
        O0 = sim.send_box(x=0, y=0, z=constants.L/2 , length=constants.L, width=constants.L, height=2*(constants.R), r=.5, g=.5, b=.5 , collision_group='robot')
        
        
        O1 = sim.send_cylinder(x=0, y=0, z=constants.L + constants.R, length = constants.L, radius = constants.R, r = 1, g=0, b=0, r1 = 0, r2 = 0, r3 = 1)
        O2 = sim.send_cylinder(x=0, y=0, z=2*(constants.L + constants.R), length = constants.L, radius = constants.R, r = 0, g=1, b=0, r1 = 0, r2 = 0, r3 = 1 , collision_group='robot')
        O3 = sim.send_cylinder(x=0, y=0, z=3*(constants.L + constants.R), length = constants.L, radius = constants.R, r = 0, g=1, b=0, r1 = 0, r2 = 0, r3 = 1 , collision_group='robot')
        O4 = sim.send_cylinder(x=0, y=0, z=4*(constants.L + constants.R), length = constants.L, radius = constants.R, r = 0, g=1, b=0, r1 = 0, r2 = 0, r3 = 1 , collision_group='robot')
        O5 = sim.send_cylinder(x=0, y=0, z=5*(constants.L + constants.R), length = constants.L, radius = constants.R, r = 0, g=1, b=0, r1 = 0, r2 = 0, r3 = 1 , collision_group='robot')
        O6 = sim.send_cylinder(x=0, y=0, z=6*(constants.L + constants.R), length = constants.L, radius = constants.R, r = 0, g=1, b=0, r1 = 0, r2 = 0, r3 = 1 , collision_group='robot')
        O7 = sim.send_cylinder(x=0, y=0, z=7*(constants.L + constants.R), length = constants.L, radius = constants.R, r = 0, g=1, b=0, r1 = 0, r2 = 0, r3 = 1 , collision_group='robot')
        O8 = sim.send_cylinder(x=0, y=0, z=8*(constants.L + constants.R), length = constants.L, radius = constants.R, r = 0, g=1, b=0, r1 = 0, r2 = 0, r3 = 1 , collision_group='robot')
        
        O9 = sim.send_box(x = -10, y = -10, z = constants.L/2*4, length = constants.L*4, width = constants.L*4, height = constants.L*4, r = 1, g = 0, b = 0 , collision_group='robot')# BOX AT A DISTANCE TO KEEP BASE IN PLACE
        O10 = sim.send_box(x = -10, y = 10, z = constants.L/2*4, length = constants.L*4, width = constants.L*4, height = constants.L*4, r = 0, g = 1, b = 0 , collision_group='robot')# BOX AT A DISTANCE TO KEEP BASE IN PLACE
        O11 = sim.send_box(x = 10, y = -10, z = constants.L/2*4, length = constants.L*4, width = constants.L*4, height = constants.L*4, r = 0, g = 0, b = 1 , collision_group='robot')# BOX AT A DISTANCE TO KEEP BASE IN PLACE
        O12 = sim.send_cylinder(x=0, y=0, z=9*(constants.L + constants.R), length = constants.L, radius = constants.R, r = 0, g=1, b=0, r1 = 0, r2 = 0, r3 = 1 , collision_group='robot')
        O13 = sim.send_cylinder(x=0, y=0, z=10*(constants.L + constants.R), length = constants.L, radius = constants.R, r = 0, g=1, b=0, r1 = 0, r2 = 0, r3 = 1 , collision_group='robot')
        
        
        sim.send_external_force(O13, x=15, y=15, z=15, time=0)
        
    def send_joints(self, sim):
        global joint, J1, J2, J3, J4, J5, J6, J7, J8, J9, J10, J11, J12
#         joint = sim.send_hinge_joint( first_body_id = redobject , second_body_id = whiteobject ,x=0,y=0,z=1.1,n1 = 1 , n2 = 0 , n3 = 0,lo=-3.14159/2 , hi=3.14159/2)
        #J0 = sim.send_hinge_joint( first_body_id = O0 , second_body_id = O1 , x = 0, y=0, z=constants.L+constants.R,     n1 = 1 , n2 = 1 , n3 = 1,lo=-3.14159 , hi=3.14159)
        #WITHOUT J0, NOTHING IS ATTACHED TO THE BASE
        J1 = sim.send_hinge_joint( first_body_id = O1 , second_body_id = O2 , x = 0, y=0, z=1.5*(constants.L+constants.R), n1 = 1 , n2 = 0 , n3 = 0,lo=-3.14159/2 , hi=3.14159/2)
        
        J2 = sim.send_hinge_joint( first_body_id = O2 , second_body_id = O3 , x = 0, y=0, z=2.5*(constants.L+constants.R), n1 = 1 , n2 = 0 , n3 = 1,lo=-3.14159/2 , hi=3.14159/2)
        J3 = sim.send_hinge_joint( first_body_id = O3 , second_body_id = O4 , x = 0, y=0, z=3.5*(constants.L+constants.R), n1 = 1 , n2 = 0 , n3 = 1,lo=-3.14159/2 , hi=3.14159/2)
        
        J4 = sim.send_hinge_joint( first_body_id = O4 , second_body_id = O5 , x = 0, y=0, z=4.5*(constants.L+constants.R), n1 = 1 , n2 = 0 , n3 = 1,lo=-3.14159/2 , hi=3.14159/2)
        J5 = sim.send_hinge_joint( first_body_id = O5 , second_body_id = O6 , x = 0, y=0, z=5.5*(constants.L+constants.R), n1 = 1 , n2 = 0 , n3 = 1,lo=-3.14159/2 , hi=3.14159/2)
        
        J6 = sim.send_hinge_joint( first_body_id = O6 , second_body_id = O7 , x = 0, y=0, z=6.5*(constants.L+constants.R), n1 = 1 , n2 = 1 , n3 = 1,lo=-3.14159/2 , hi=3.14159/2)
        J7 = sim.send_hinge_joint( first_body_id = O7 , second_body_id = O8 , x = 0, y=0, z=7.5*(constants.L+constants.R), n1 = 1 , n2 = 1 , n3 = 1,lo=-3.14159/2 , hi=3.14159/2)
        
        #J8 = sim.send_hinge_joint( first_body_id = O0 , second_body_id = O9 , x = 0, y=0, z=constants.R, n1 = 0, n2 = 1, n3 = 1, lo=-3.14159 , hi=3.14159) # impossible joint connecting base to far block
        #J9 = sim.send_hinge_joint( first_body_id = O0 , second_body_id = O10 , x = 0, y=0, z=constants.R, n1 = 1, n2 = 1, n3 = 1, lo=-3.14159 , hi=3.14159) # impossible joint connecting base to far block
        #J10 = sim.send_hinge_joint( first_body_id = O0 , second_body_id = O11 , x = 0, y=0, z=constants.R, n1 = 1, n2 = 1, n3 = 1, lo=-3.14159 , hi=3.14159) # impossible joint connecting base to far block
        
        J11 = sim.send_hinge_joint( first_body_id = O8 , second_body_id = O12 , x = 0, y=0, z=8.5*(constants.L+constants.R), n1 = 1, n2 = 0, n3 = 1, lo=-3.14159/2 , hi=3.14159/2) # impossible joint connecting base to far block
        J12 = sim.send_hinge_joint( first_body_id = O12 , second_body_id = O13 , x = 0, y=0, z=9.5*(constants.R+constants.L), n1 = 1, n2 = 0, n3 = 1, lo=-3.14159/2 , hi=3.14159/2) # impossible joint connecting base to far block
        
        
        
        
        
        
    def send_sensors(self, sim):
        global T0, T1, T2, T3, T4, T5, T6, T7, T8, T9, P2, R3, P4
        self.T0 = sim.send_touch_sensor( body_id = O1 )
        self.T1 = sim.send_touch_sensor( body_id = O2 )
        self.T2 = sim.send_touch_sensor( body_id = O3 )
        self.T3 = sim.send_touch_sensor( body_id = O4 )
        self.T4 = sim.send_touch_sensor( body_id = O5 )
        self.T5 = sim.send_touch_sensor( body_id = O6 )
        self.T6 = sim.send_touch_sensor( body_id = O7 )
        self.T7 = sim.send_touch_sensor( body_id = O8 )
        self.T8 = sim.send_touch_sensor( body_id = O12 )
        self.T9 = sim.send_touch_sensor( body_id = O13 )
#         self.P4 = sim.send_position_sensor( body_id = O0 )
        self.L4 = sim.send_light_sensor( body_id = O1 )
        self.L5 = sim.send_light_sensor( body_id = O2 )
        self.L6 = sim.send_light_sensor( body_id = O3 )
        self.L7 = sim.send_light_sensor( body_id = O4 )
        self.L8 = sim.send_light_sensor( body_id = O5 )
        self.L9 = sim.send_light_sensor( body_id = O6 )
        self.L10 = sim.send_light_sensor( body_id = O7 )
        self.L11 = sim.send_light_sensor( body_id = O8 )
        self.L12 = sim.send_light_sensor( body_id = O12 )
        self.L13 = sim.send_light_sensor( body_id = O13 )
        
        
#         T0 = sim.send_touch_sensor( body_id = whiteobject )
#         T1 = sim.send_touch_sensor( body_id = redobject )
#         P2 = sim.send_proprioceptive_sensor( joint_id = joint )

#         R3 = sim.send_ray_sensor( body_id = redobject , x = 0 , y = 1.1 , z = 1.1 , r1 = 0 , r2 = 1, r3 = 0)
#         self.P4 = sim.send_position_sensor( body_id = redobject)
# #         self.P4 = sim.send_position_sensor( body_id = redobject)
    
        
    def send_neurons(self, sim):
        global SN0, SN1, SN2, SN3, SN4, SN5, SN6, SN7, SN8, SN9, SN10, SN11, MN4, MN5, MN6, MN7, MN8, MN9, MN10, MN11
        global sensorNeurons, motorNeurons
        
        self.O = {}
        self.O[0] = O0
        self.O[1] = O1
        self.O[2] = O2
        self.O[3] = O3
        self.O[4] = O4
        self.O[5] = O5
        self.O[6] = O6
        self.O[7] = O7
        self.O[8] = O8
        self.O[9] = O12
        self.O[10] = O13
        
        
        
        self.J = {}
        #self.J[0] = J0
        self.J[1] = J1
        self.J[2] = J2
        self.J[3] = J3
        self.J[4] = J4
        self.J[5] = J5
        self.J[6] = J6
        self.J[7] = J7
        self.J[8] = J11
        self.J[9] = J12
        
        
        self.S = {}
        self.S[0] = self.T0
        self.S[1] = self.T1
        self.S[2] = self.T2
        self.S[3] = self.T3
        self.S[4] = self.L4
        self.S[5] = self.L5
        self.S[6] = self.L6
        self.S[7] = self.L7
        self.S[8] = self.L8
        self.S[9] = self.L9
        self.S[10] = self.L10
        self.S[11] = self.L11
        self.S[12] = self.L12
        self.S[13] = self.L13
        self.S[14] = self.T8
        self.S[15] = self.T9
        
        
        self.SN = {}
#         self.SN[0] = SN0
#         self.SN[1] = SN1
#         self.SN[2] = SN2
#         self.SN[3] = SN3
        
        
        self.MN = {}
#         MN[0] = MN4
#         MN[1] = MN5
#         MN[2] = MN6
#         MN[3] = MN7
#         MN[4] = MN8
#         MN[5] = MN9
#         MN[6] = MN10
#         MN[7] = MN11



        for s in self.S:
            self.SN[s] = sim.send_sensor_neuron(sensor_id = self.S[s])
            
            
        for j in self.J:
            self.MN[j] = sim.send_motor_neuron(joint_id = self.J[j], tau = .5)







        
#         SN0 = sim.send_sensor_neuron( sensor_id = T0 )
#         SN1 = sim.send_sensor_neuron( sensor_id = T1 )
#         SN2 = sim.send_sensor_neuron( sensor_id = P2 )
#         SN3 = sim.send_sensor_neuron( sensor_id = R3 )
#         MN2 = sim.send_motor_neuron( joint_id = joint )
        
        
        
    def send_synapses(self, sim, wts):
        
        for sn in self.SN:
            
            firstMN = min( self.MN , key = self.MN.get)
            
            sim.send_synapse(source_neuron_id = self.SN[sn] , target_neuron_id = self.MN[firstMN] , weight = random.random()*2-1)
        
        for j in self.SN:
            for i in self.MN:
#                 print(wts)
#                 print(j)
#                 print(i)
#                 print(self.SN[j])
#                 print(wts[j,i])
                sim.send_synapse(source_neuron_id = self.SN[j], target_neuron_id = self.MN[i],  weight = wts[j,i])
        
        
        
#         for s in sensorNeurons:
#             for m in motorNeurons:
#                 sim.send_synapse( source_neuron_id = sensorNeurons[s] , target_neuron_id = motorNeurons[m] , weight = wts[s] )
